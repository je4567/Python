# %%
def simple_interest(p,r,t):
   si=[p*r*t]/100
   return si

# %%
def compound_interest(p,r,t):
   amount=p*(1+r/100)**t
   ci=amount-p
   return ci

# %%
n=int(input("enter the number of customers"))
for i in range(n):
    print("\n customers",i+1)
    p=int(input("enter the principle:"))
    r=int(input("enter the rate:"))
    t=int(input("enter the time:"))
    si=simple_interest(p,r,t)
    ci=compound_interest(p,r,t)
    print("simple_interest",si)
    print("compound_interest",ci)
# Out:
# enter the number of customers 3
#  customers 1
# enter the principle: 45678
# enter the rate: 6
# enter the time: 7
# simple_interest [1918476]
# compound_interest 23004.822970207373
#
#  customers 2
# enter the principle: 56680
# enter the rate: 3
# enter the time: 8
# simple_interest [1360320]
# compound_interest 15120.5282130501
#
#  customers 3
# enter the principle: 65432
# enter the rate: 3
# enter the time: 12
# simple_interest [2355552]
# compound_interest 27858.38634811921
